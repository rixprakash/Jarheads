# %% [markdown]
# <a href="https://colab.research.google.com/github/rixprakash/Jarheads/blob/main/Project%202/DATA/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/rixprakash/Jarheads
# Out:
# Cloning into 'Jarheads'...
# remote: Enumerating objects: 693, done.
# remote: Counting objects: 100% (143/143), done.
# remote: Compressing objects: 100% (81/81), done.
# remote: Total 693 (delta 112), reused 60 (delta 60), pack-reused 550 (from 1)
# Receiving objects: 100% (693/693), 110.63 MiB | 11.53 MiB/s, done.
# Resolving deltas: 100% (349/349), done.

# %%
# prompt: make a new file where you merge the /content/Jarheads/Project 2/DATA/CBOE Volatility Index Historical Data.csv and /content/Jarheads/Project 2/DATA/SPY ETF Stock Price History.csv based on the same date. Add it to the priject 2 data folder

import pandas as pd
import os

# Define file paths
vix_file = '/content/Jarheads/Project 2/DATA/CBOE Volatility Index Historical Data.csv'
spy_file = '/content/Jarheads/Project 2/DATA/SPY ETF Stock Price History.csv'
output_file = '/content/Jarheads/Project 2/DATA/merged_data.csv'

# Check if the files exist
if not os.path.exists(vix_file) or not os.path.exists(spy_file):
  print("Error: One or both input files not found.")
else:
  try:
    # Read the CSV files into pandas DataFrames
    vix_df = pd.read_csv(vix_file)
    spy_df = pd.read_csv(spy_file)

    # Convert the 'Date' column to datetime objects
    vix_df['Date'] = pd.to_datetime(vix_df['Date'])
    spy_df['Date'] = pd.to_datetime(spy_df['Date'])

    # Merge the DataFrames based on the 'Date' column
    stockmarketdata = pd.merge(vix_df, spy_df, on='Date', how='inner')

    # Save the merged DataFrame to a new CSV file
    merged_df.to_csv(output_file, index=False)
    print(f"Merged data saved to {output_file}")

  except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Merged data saved to /content/Jarheads/Project 2/DATA/merged_data.csv
